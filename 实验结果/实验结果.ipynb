# %% [markdown]
# ssh -p 27533 root@connect.nmb1.seetacloud.com<br>
# 这台主机上存放了除CUB外的cifar、ina、inr、vtab的数据

# %%
def get_average(map):
    sum = 0
    length = len(map)
    for val in map.values():
        sum += val
    return sum / length

# %%
'''ImageNet-A'''
map = {0: 86.32,
       1: 81.28,
       2: 75.70,
       3: 73.88,
       4: 71.92,
       5: 68.19,
       6: 64.92,
       7: 63.09,
       8: 60.42,
       9: 59.78,
       }
# A_bar = get_average(map)
A_bar = 70.55

# %%
'''VTAB'''
map = {0: 93.10,
       1: 90.29,
       2: 91.57,
       3: 87.04,
       4: 88.27,
       }
# A_bar = get_average(map)
A_bar = 90.05
# Out:
# 90.054

# %%
'''CIFAR100'''
map = {0: 99.00,
       1: 98.70,
       2: 95.47,
       3: 95.55,
       4: 95.32,
       5: 93.83,
       6: 93.37,
       7: 91.97,
       8: 91.82,
       9: 90.76,
       10: 90.22,
       11: 89.63,
       12: 89.03,
       13: 89.14,
       14: 88.11,
       15: 88.15,
       16: 87.88,
       17: 88.30,
       18: 88.26,
       19: 87.59,
       }
A_bar = get_average(map)
A_bar
